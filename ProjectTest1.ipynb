# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Nutrientfilefinal.csv")
df
# Out:
#      Public Food Key  Classification  \
# 0            F002258         31302.0
# 1            F002893         31302.0
# 2            F002963         31302.0
# 3            F002970         31302.0
# 4            F003190         31302.0
# ...              ...             ...
# 1611         F009774         24702.0
# 1612         F009773         24702.0
# 1613         F009766         24702.0
# 1614         F009765         24702.0
# 1615         F009764         24702.0
#
#                                               Food Name  \
# 0                          Cardamom seed, dried, ground
# 1                         Chilli (chili), dried, ground
# 2                               Cinnamon, dried, ground
# 3                                 Cloves, dried, ground
# 4                         Coriander seed, dried, ground
# ...                                                 ...
# 1611  Zucchini, green skin, fresh, unpeeled, fried, ...
# 1612  Zucchini, green skin, fresh, unpeeled, boiled,...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1616 entries, 0 to 1615
# Data columns (total 31 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Public Food Key                                      1616 non-null   object
#  1   Classification                                       1614 non-null   float64
#  2   Food Name                                            1616 non-null   object
#  3   Energy with dietary fibre, equated
# (kJ)             1616 non-null   object
#  4   Moisture (water)
# (g)                                1616 non-null   float64
#  5   Protein
# (g)                                         1616 non-null   float64
#  6   Nitrogen
# (g)                                        1616 non-null   float64
#  7   Fat, total
# (g)                                      1616 non-null   float64
#  8   Total dietary fibre
# ...

# %%
df.head(2)
# Out:
#   Public Food Key  Classification                      Food Name  \
# 0         F002258         31302.0   Cardamom seed, dried, ground
# 1         F002893         31302.0  Chilli (chili), dried, ground
#
#   Energy with dietary fibre, equated \n(kJ)  Moisture (water) \n(g)  \
# 0                                     1,236                     8.3
# 1                                     1,280                    10.8
#
#    Protein \n(g)  Nitrogen \n(g)  Fat, total \n(g)  Total dietary fibre \n(g)  \
# 0           10.8            1.72               6.7                       28.0
# 1           13.4            2.14              14.3                       34.8
#
#    Glucose \n(g)  ...  Potassium (K) \n(mg)  Sodium (Na) \n(mg)  \
# 0            NaN  ...                 1,119                  18
# 1            NaN  ...                 1,950               2,867
#
#    Zinc (Zn) \n(mg)  Cobalamin (B12) \n(ug)  Folic acid \n(ug)  \
# ...

# %%
df.shape
# Out:
# (1616, 31)

# %%
df.isnull().sum()
# Out:
# Public Food Key                                           0
# Classification                                            2
# Food Name                                                 0
# Energy with dietary fibre, equated \n(kJ)                 0
# Moisture (water) \n(g)                                    0
# Protein \n(g)                                             0
# Nitrogen \n(g)                                            0
# Fat, total \n(g)                                          0
# Total dietary fibre \n(g)                                 0
# Glucose \n(g)                                           192
# Added sugars (g)                                          0
# Free sugars \n(g)                                         0
# Starch \n(g)                                              0
# Available carbohydrate, without sugar alcohols \n(g)      0
# Available carbohydrate, with sugar alcohols \n(g)         0
# Calcium (Ca) \n(mg)                                       0
# ...

# %%
# This will give what %tage of each column's data is null
# In our case, 0 %tage of each column's data is null
# Which means no data Filling is needed
p = df.isnull().sum()
p = p/len(df)*100
p
# Out:
# Public Food Key                                          0.000000
# Classification                                           0.123762
# Food Name                                                0.000000
# Energy with dietary fibre, equated \n(kJ)                0.000000
# Moisture (water) \n(g)                                   0.000000
# Protein \n(g)                                            0.000000
# Nitrogen \n(g)                                           0.000000
# Fat, total \n(g)                                         0.000000
# Total dietary fibre \n(g)                                0.000000
# Glucose \n(g)                                           11.881188
# Added sugars (g)                                         0.000000
# Free sugars \n(g)                                        0.000000
# Starch \n(g)                                             0.000000
# Available carbohydrate, without sugar alcohols \n(g)     0.000000
# ...

# %%
df['Classification'].unique()
# Out:
# array([3.1302e+04, 3.1301e+04, 3.1303e+04, 3.1501e+04, 3.1502e+04,
#        1.2103e+04, 2.4102e+04, 3.1401e+04, 3.1101e+04, 2.9101e+04,
#        2.9102e+04, 2.9301e+04, 2.9401e+04, 2.9201e+04, 2.9202e+04,
#        2.9203e+04, 3.0105e+04, 3.0104e+04, 1.1804e+04, 1.1802e+04,
#        1.1803e+04, 1.1801e+04, 1.1205e+04, 1.1201e+04, 1.1203e+04,
#        1.1209e+04, 1.1208e+04, 1.1202e+04, 1.1403e+04, 1.1401e+04,
#        1.1307e+04, 1.1301e+04, 2.2203e+04, 1.1702e+04, 1.1505e+04,
#        1.1503e+04, 1.1504e+04, 1.1603e+04, 1.1501e+04, 1.1502e+04,
#        2.9505e+04, 1.1101e+04, 1.1103e+04, 1.1701e+04, 1.3204e+04,
#        1.3202e+04, 1.3201e+04, 1.3205e+04, 1.3203e+04, 1.3200e+02,
#        1.3101e+04, 1.3102e+04, 1.3105e+04,        nan, 1.3106e+04,
#        1.3104e+04, 1.2201e+04, 1.2302e+04, 1.2207e+04, 1.2202e+04,
#        1.2203e+04, 1.2304e+04, 1.2204e+04, 1.2305e+04, 1.2307e+04,
#        1.2213e+04, 1.2210e+04, 1.2306e+04, 1.3606e+04, 1.2301e+04,
# ...
